# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import os

for dirname, _, filenames in os.walk('/content/drive/MyDrive/gas_data/'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
temp2013=pd.read_csv('/content/drive/MyDrive/gas_data/temp2013.csv', encoding='cp949') 
temp2014=pd.read_csv('/content/drive/MyDrive/gas_data/temp2014.csv', encoding='cp949')
temp2015=pd.read_csv('/content/drive/MyDrive/gas_data/temp2015.csv', encoding='cp949')
temp2016=pd.read_csv('/content/drive/MyDrive/gas_data/temp2016.csv', encoding='cp949') 
temp2017=pd.read_csv('/content/drive/MyDrive/gas_data/temp2017.csv', encoding='cp949') 
temp2018=pd.read_csv('/content/drive/MyDrive/gas_data/temp2018.csv', encoding='cp949')
oil=pd.read_csv('/content/drive/MyDrive/gas_data/oil.csv', encoding='cp949')
supply_index=pd.read_csv('/content/drive/MyDrive/gas_data/supply_index.csv', encoding='cp949')
demand_index=pd.read_csv('/content/drive/MyDrive/gas_data/demand_index.csv', encoding='cp949')
electricity=pd.read_csv('/content/drive/MyDrive/gas_data/electricity.csv', encoding='cp949')
import_index=pd.read_csv('/content/drive/MyDrive/gas_data/import_index.csv', encoding='cp949')
main=pd.read_csv('/content/drive/MyDrive/gas_data/main.csv', encoding='cp949')

# %%
#  '가스'가 포함된 행 추출
import_index = import_index[import_index['계정코드별'].str.contains('가스', na = False)]

# %%
import_index.drop(['Unnamed: 76'], axis=1, inplace=True)

# %%
import_index.head()
